# %% [markdown]
# <a href="https://colab.research.google.com/github/Somtochukwu-Achikanu/Projects/blob/main/Lively_Seeds_Group_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install whatstk
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 49.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 63.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 26.1 MB/s eta 0:00:00
# ...
#   Created wheel for whatstk: filename=whatstk-0.6.2-py3-none-any.whl size=60397 sha256=353935142d3e8eb3fd39694bd1e93ebe6b010d6300b22bc4c9f9a839275770a2
#   Stored in directory: /root/.cache/pip/wheels/62/1e/f2/69386e57a388ed2a9f8e19db1cc95ccd735dd6a521dd686b00
# ...
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234912 sha256=b28cebdecc4779045d081aa83d332a82bfa67d7c86cee661b89ade977e23d05c
# ...

# %%
# !pip install emot

# %%
# !pip install stylecloud
# Out:
# ...
#   Using cached stylecloud-0.5.2.tar.gz (262 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached icon_font_to_png-0.4.1-py2.py3-none-any.whl (161 kB)
# ...
#   Using cached palettable-3.3.3-py2.py3-none-any.whl (332 kB)
# ...
#   Using cached fire-0.6.0.tar.gz (88 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached tinycss-0.4.tar.gz (87 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for stylecloud: filename=stylecloud-0.5.2-py3-none-any.whl size=259494 sha256=ad2b0f8224f77823ec71b47f32baededfbbd311a80f9ed83ffb0505bdbfdcbef
#   Stored in directory: /root/.cache/pip/wheels/aa/c8/27/9374f4fc7133015d902b5e2c75ad951edd57eb1ae948495915
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=f25cea6f3c2c67abd5836b34b118755398418ac3e82df9cad383f8fe63215f29
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# ...

# %%
from whatstk import WhatsAppChat
from whatstk import df_from_txt_whatsapp
chat = WhatsAppChat.from_source(filepath='/content/_chat.txt', hformat="[%d/%m/%y, %H:%M:%S] %name:").df
print(chat.head())
# Out:
#                  date             username  \
# 0 2016-12-05 21:56:14  LIVELYSEED FAMILY 🌷
# 1 2016-12-05 21:56:14  ‪+234 706 212 1211‬
# 2 2016-12-05 21:56:14  LIVELYSEED FAMILY 🌷
# 3 2019-12-11 14:54:20           Pastor Uba
# 4 2019-12-11 14:54:43           Pastor Uba
#
#                                              message
# 0  ‎Messages and calls are end-to-end encrypted. ...
# 1            ‎‪+234 706 212 1211‬ created this group
# 2                                    ‎You were added
# 3  https://youtu.be/KP43OXnZOow
#
# Summit of the Na...
# 4                       https://youtu.be/UDAcGn2SL6A

# %% [markdown]
# # Overview of the groupchat

# %%
#Earliest date of the chat and latest date of the chat

earliest_date = chat.date.min()
latest_date = chat.date.max()

print("The date the group chat was created was on", earliest_date, "and the latest date for this analysis is", latest_date)
# Out:
# The date the group chat was created was on 2016-12-05 21:56:14 and the latest date for this analysis is 2024-02-01 22:24:38

# %%
#Number of messages and users
stats = chat.groupby('username')['message'].agg('count')
stats
# Out:
# username
# Ada Agwara              360
# Amarachi Achikanu       570
# Angel Opoku             420
# Aunty Ada Nkwueke      1485
# Aunty Ajulu             289
#                        ...
# ‪+234 810 572 7535‬       1
# ‪+234 813 774 9668‬       2
# ‪+234 816 913 0490‬       1
# ‪+234 906 094 6747‬       3
# ‪+234 913 851 3470‬       1
# Name: message, Length: 133, dtype: int64

# %%
#Number of messages per user
stats = chat.groupby('username')['message'].count().reset_index().sort_values(by='message', ascending=False)
stats.columns = ['Username', 'Total Messages']

#reset Index
stats = stats.reset_index(drop=True)
print(stats)
# Out:
#                     Username  Total Messages
# 0                 Pastor Uba            1947
# 1          Aunty Ada Nkwueke            1485
# 2            Aunty Nkiru LSA            1463
# 3                    Mum MTN            1365
# 4    Uncle Chima Onwuka-kalu            1252
# ..                       ...             ...
# 128             Bro Jude LSA               1
# 129        Samuel Achikanu 2               1
# 130    Precious Onwuka-kalu                1
# 131         Chiedozie Asogwa               1
# 132      ‪+234 913 851 3470‬               1
#
# [133 rows x 2 columns]

# %% [markdown]
# Pastor uba is the most active username and His user name has come contributed a total of about 2947 messages within the time frame of this analysis

# %%
import plotly.express as px
import plotly.graph_objects as go

# Create the bar plot
fig = go.Figure(data = go.Bar(x=stats['Username'], y=stats['Total Messages']))
fig.update_layout(title='Most Active User', xaxis_title='Username', yaxis_title='Total Messages')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Number of messages per user
stats_20 = chat.groupby('username')['message'].count().reset_index().sort_values(by='message', ascending=False)
stats_20.columns = ['Username', 'Total Messages']

#reset Index
stats_20 = stats_20.reset_index(drop=True)
Top_20 = stats_20.head(n=20)
print(Top_20)
# Out:
#                    Username  Total Messages
# 0                Pastor Uba            1947
# 1         Aunty Ada Nkwueke            1485
# 2           Aunty Nkiru LSA            1463
# 3                   Mum MTN            1365
# 4   Uncle Chima Onwuka-kalu            1252
# 5         Bro Jude Achikanu            1021
# 6          ~ blessedbridget            1019
# 7               Aunty Norah             977
# 8            Sis Oluchi LSA             948
# 9         Barrister Gab LSA             817
# 10         Bro Adamu Bitrus             697
# 11         Sis Chinasa LSA              681
# 12                Aunty Oby             679
# 13      Bro Jude Ozoemena 2             613
# 14         Aunty Peace Okey             611
# 15        Amarachi Achikanu             570
# 16          Bro Vincent LSA             552
# 17               Pastor Cos             551
# 18    Aunty Ijeoma Ofurunna             540
# 19       Blessing Achikanu              505

# %%
#Plotting the most active 20 users of the group
# Create the bar plot
fig = go.Figure(data = go.Bar(x=Top_20['Username'], y=Top_20['Total Messages'],text =Top_20['Total Messages'],textposition = 'auto'))
fig.update_layout(title='Most Active 20 Users of This Group', xaxis_title='Username', yaxis_title='Total Messages')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Using FigureBuilder Library to plot a Line chart

# %%
from whatstk import FigureBuilder
from plotly.offline import plot
fb = FigureBuilder(chat)
fig = fb.user_interventions_count_linechart(cumulative=True, title='User inteventions count (cumulative)')
plot(fig)
# Out:
# 'temp-plot.html'

# %% [markdown]
# # Preparing the Data

# %%
import pandas as pd

# Convert 'date' column to datetime type
chat['date'] = pd.to_datetime(chat['date'])

# Extract time into a separate column
chat['Time'] = chat['date'].dt.time

print(chat.head())
# Out:
#                  date             username  \
# 0 2016-12-05 21:56:14  LIVELYSEED FAMILY 🌷
# 1 2016-12-05 21:56:14  ‪+234 706 212 1211‬
# 2 2016-12-05 21:56:14  LIVELYSEED FAMILY 🌷
# 3 2019-12-11 14:54:20           Pastor Uba
# 4 2019-12-11 14:54:43           Pastor Uba
#
#                                              message      Time
# 0  ‎Messages and calls are end-to-end encrypted. ...  21:56:14
# 1            ‎‪+234 706 212 1211‬ created this group  21:56:14
# 2                                    ‎You were added  21:56:14
# 3  https://youtu.be/KP43OXnZOow
#
# Summit of the Na...  14:54:20
# 4                       https://youtu.be/UDAcGn2SL6A  14:54:43

# %%
import pandas as pd

# Convert 'date' column to datetime type
chat['date'] = pd.to_datetime(chat['date'])

# Extract time into a separate column
chat['Time'] = chat['date'].dt.time

# Create 'year' and 'month' columns
chat['Year'] = chat['date'].dt.year
chat['Month'] = chat['date'].dt.strftime('%B')
chat['Day Name'] = chat['date'].dt.day_name()

# Remove time from the 'date' column
chat['date'] = chat['date'].dt.date

# Print the updated DataFrame
print(chat.head())
# Out:
#          date             username  \
# 0  2016-12-05  LIVELYSEED FAMILY 🌷
# 1  2016-12-05  ‪+234 706 212 1211‬
# 2  2016-12-05  LIVELYSEED FAMILY 🌷
# 3  2019-12-11           Pastor Uba
# 4  2019-12-11           Pastor Uba
#
#                                              message      Time  Year  \
# 0  ‎Messages and calls are end-to-end encrypted. ...  21:56:14  2016
# 1            ‎‪+234 706 212 1211‬ created this group  21:56:14  2016
# 2                                    ‎You were added  21:56:14  2016
# 3  https://youtu.be/KP43OXnZOow
#
# Summit of the Na...  14:54:20  2019
# 4                       https://youtu.be/UDAcGn2SL6A  14:54:43  2019
#
#       Month   Day Name
# 0  December     Monday
# 1  December     Monday
# 2  December     Monday
# 3  December  Wednesday
# 4  December  Wednesday

# %% [markdown]
# # Determining the number of messages sent each day and the Most Active Year

# %%
#Number of messages sent each day
stats = chat.groupby('date')['message'].size().reset_index(name='total_messages').sort_values(by='total_messages', ascending=False)
print(stats)
# Out:
#            date  total_messages
# 109  2020-04-05             790
# 112  2020-04-08             622
# 137  2020-05-03             574
# 123  2020-04-19             532
# 144  2020-05-10             493
# ..          ...             ...
# 271  2020-09-18               1
# 764  2022-02-04               1
# 297  2020-10-14               1
# 299  2020-10-16               1
# 653  2021-10-16               1
#
# [1473 rows x 2 columns]

# %% [markdown]
# From the result,it can be seen that the group was most active on the 5th of march,2020 and this would be most likely due to the covid and the increased online presence that is online bible study, prayer meetings.

# %%
import plotly as px
import plotly.graph_objects as go

# Group the DataFrame by year and get the count of messages
yearly_stats = chat.groupby(chat['Year'])['message'].count().reset_index()
yearly_stats.columns = ['Year', 'Total Messages']

# Sort the yearly statistics in descending order
yearly_stats = yearly_stats.sort_values(by='Total Messages', ascending=False)

# Create the bar plot
fig = go.Figure(data=go.Bar(x=yearly_stats['Year'], y=yearly_stats['Total Messages']))

# Update the layout
fig.update_layout(title='Most Active Year', xaxis_title='Year', yaxis_title='Total Messages')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Since 2020, is the most active year..Lets see which day of the week and Month was the most active??

# %%
#Filter the year 2020
year_2020 = chat[chat['Year'] == 2020]
print(year_2020)

# Group the DataFrame by year and get the count of messages
Weekday_stats = year_2020.groupby(year_2020['Day Name'])['message'].count().reset_index()
Weekday_stats.columns = ['Day Name', 'Total Messages']

# Sort the yearly statistics in descending order
Weekday_stats = Weekday_stats.sort_values(by='Total Messages', ascending=False)

# Create the bar plot
fig = go.Figure(data=go.Bar(x=Weekday_stats['Day Name'], y=Weekday_stats['Total Messages']))

# Update the layout
fig.update_layout(title='Most Active Day in 2020', xaxis_title='Days', yaxis_title='Total Messages')

# Show the plot
fig.show()
# Out:
#              date                  username  \
# 210    2020-01-01           Aunty Nkiru LSA
# 211    2020-01-01         Aunty Ada Nkwueke
# 212    2020-01-01         Aunty Ada Nkwueke
# 213    2020-01-01          Aunty Peace Okey
# 214    2020-01-01         Aunty Ada Nkwueke
# ...           ...                       ...
# 18408  2020-12-30         Chisom Uzoechina
# 18409  2020-12-31                   Mum MTN
# 18410  2020-12-31               Aunty Norah
# 18411  2020-12-31  Izuchukwu Arthur Okonkwo
# 18412  2020-12-31   Uncle Chima Onwuka-kalu
#
#                                                  message      Time  Year  \
# 210    GOD INDEED DESERVES ALL THE PRAISE.
# HAPPY NEW...  00:13:42  2020
# 211                      Hallelujah, to our God Almighty  00:16:07  2020
# 212                                    Happy  new Decade  00:16:07  2020
# 213    Thank God we all crossed over, may the Lord bl...  00:22:07  2020
# ...

# %%
#Most active Month in 2020

# Group the DataFrame by year and get the count of messages
Weekday_stats = year_2020.groupby(year_2020['Month'])['message'].count().reset_index()
Weekday_stats.columns = ['Month', 'Total Messages']

# Sort the yearly statistics in descending order
Weekday_stats = Weekday_stats.sort_values(by='Total Messages', ascending=False)

# Create the bar plot
fig = go.Figure(data=go.Bar(x=Weekday_stats['Month'], y=Weekday_stats['Total Messages']))

# Update the layout
fig.update_layout(title='Most Active Month in the most active year,2020', xaxis_title='Month', yaxis_title='Total Messages')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
year_2020.dtypes
# Out:
# date        object
# username    string
# message     string
# Time        object
# Year         int64
# Month       object
# Day Name    object
# dtype: object

# %% [markdown]
# # Determining the most Time the group was active in 2020

# %%
#Filter the year 2020
year_2020 = chat[chat['Year'] == 2020]

# Group the DataFrame by year and get the count of messages
Weekday_stats = year_2020.groupby(year_2020['Time'])['message'].count().reset_index()
Weekday_stats.columns = ['Time', 'Total Messages']

# Sort the yearly statistics in descending order
Weekday_stats = Weekday_stats.sort_values(by='Total Messages', ascending=False)

# Create the bar plot
fig = go.Figure(data=go.Bar(x=Weekday_stats['Time'], y=Weekday_stats['Total Messages']))
fig.update_layout(title='Most Active Time in 2020', xaxis_title='Time', yaxis_title='Total Messages')


# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **summary: The activity in the group was high towards the evenings...around 5pm and 6pm in the evenings**

# %%
#To analyse the time on wednesday and sunday the group was active

# %% [markdown]
# # Emoji Analysis, Word Cloud and Sentiment Analysis

# %%
import emoji, emot, re, stylecloud
import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer

from nltk.corpus import stopwords

from nltk.tokenize import word_tokenize

from nltk.stem import WordNetLemmatizer



import nltk

nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# ...

# %%
#Cleaning the Texts
def clean_text(text):
    text = text.replace('<Media omitted>', '').replace('This message was deleted', '').replace('\n', ' ').replace('video omitted', '').replace('image omitted', '').strip()
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'[0-9]+','', text)
    text = re.sub(r'\s+',' ', text)
    text = re.sub(r'[^\w\s]|_', '', text)
    text = re.sub(r'([a-zA-Z])\1\1','\\1', text)

    # Tokenize the text

    tokens = word_tokenize(text.lower())

    # Remove stop words

    filtered_tokens = [token for token in tokens if token not in stopwords.words('english')]

    # Lemmatize the tokens

    lemmatizer = WordNetLemmatizer()

    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]


    # Join the tokens back into a string

    clean_text = ' '.join(lemmatized_tokens)
    return clean_text

chat['clean_message'] = chat['message'].apply(clean_text)
print(chat.head())
# Out:
#          date             username  \
# 0  2016-12-05  LIVELYSEED FAMILY 🌷
# 1  2016-12-05  ‪+234 706 212 1211‬
# 2  2016-12-05  LIVELYSEED FAMILY 🌷
# 3  2019-12-11           Pastor Uba
# 4  2019-12-11           Pastor Uba
#
#                                              message      Time  Year  \
# 0  ‎Messages and calls are end-to-end encrypted. ...  21:56:14  2016
# 1            ‎‪+234 706 212 1211‬ created this group  21:56:14  2016
# 2                                    ‎You were added  21:56:14  2016
# 3  https://youtu.be/KP43OXnZOow
#
# Summit of the Na...  14:54:20  2019
# 4                       https://youtu.be/UDAcGn2SL6A  14:54:43  2019
#
#       Month   Day Name                                      clean_message
# 0  December     Monday  message call endtoend encrypted one outside ch...
# 1  December     Monday                                      created group
# 2  December     Monday                                              added
# ...

# %%
#Extracting the emoji
chat['emoji'] = chat['message'].apply(lambda x: ''.join(a for a in x if a in emoji.EMOJI_DATA))
print(chat.head())
# Out:
#          date             username  \
# 0  2016-12-05  LIVELYSEED FAMILY 🌷
# 1  2016-12-05  ‪+234 706 212 1211‬
# 2  2016-12-05  LIVELYSEED FAMILY 🌷
# 3  2019-12-11           Pastor Uba
# 4  2019-12-11           Pastor Uba
#
#                                              message      Time  Year  \
# 0  ‎Messages and calls are end-to-end encrypted. ...  21:56:14  2016
# 1            ‎‪+234 706 212 1211‬ created this group  21:56:14  2016
# 2                                    ‎You were added  21:56:14  2016
# 3  https://youtu.be/KP43OXnZOow
#
# Summit of the Na...  14:54:20  2019
# 4                       https://youtu.be/UDAcGn2SL6A  14:54:43  2019
#
#       Month   Day Name                                      clean_message  \
# 0  December     Monday  message call endtoend encrypted one outside ch...
# 1  December     Monday                                      created group
# 2  December     Monday                                              added
# ...

# %%
chat = chat.sort_values(by='emoji', ascending=False)
chat_emoji = chat.groupby('username').agg({
                              'emoji': lambda x: ' '.join(set(emoji for emojis in x.dropna() for emoji in emojis))
                              })
print(chat_emoji.head())
# Out:
#                                                                emoji
# username
# Ada Agwara                                             ❤ 🌹 💪 🙏 ✋ 👎 👍
# Amarachi Achikanu  ❤ 😂 🤷 🤧 👆 🥳 🙄 💃 🙈 ♀ 🏼 😅 🤣 🥂 ❌ 🙋 🙌 😫 🏾 🙃 🎂 🌚 🤭 ...
# Angel Opoku                          💃 😂 🏽 🎊 🎉 🍾 😊 🥰 🎂 😍 🙂 👍 🤣 🎈 🙄 😃
# Aunty Ada Nkwueke  🤍 🌍 ☘ 😳 💯 🎹 😭 🙌 😊 😘 👉 🌞 ✋ 🤗 🕺 😂 👩 🤷 🤫 👆 💕 🛏 💥 ...
# Aunty Ajulu                                              👏 😈 🏼 🙇 🙏 ♂

# %%
# Count the emojis used by each person
chat_emoji['Emoji Count'] = chat_emoji['emoji'].apply(lambda x: len(x.split()))

# Reset the index to remove the duplicate 'username' column
chat_emoji = chat_emoji.reset_index()
print(chat_emoji.head(20))
# Out:
#                  username                                              emoji  \
# 0              Ada Agwara                                      ❤ 🌹 💪 🙏 ✋ 👎 👍
# 1       Amarachi Achikanu  ❤ 😂 🤷 🤧 👆 🥳 🙄 💃 🙈 ♀ 🏼 😅 🤣 🥂 ❌ 🙋 🙌 😫 🏾 🙃 🎂 🌚 🤭 ...
# 2             Angel Opoku                    💃 😂 🏽 🎊 🎉 🍾 😊 🥰 🎂 😍 🙂 👍 🤣 🎈 🙄 😃
# 3       Aunty Ada Nkwueke  🤍 🌍 ☘ 😳 💯 🎹 😭 🙌 😊 😘 👉 🌞 ✋ 🤗 🕺 😂 👩 🤷 🤫 👆 💕 🛏 💥 ...
# 4             Aunty Ajulu                                        👏 😈 🏼 🙇 🙏 ♂
# 5   Aunty Chinenye Nwafor                                      🍾 🎊 🎉 💐 🙏 🍻 🌲
# 6   Aunty Ijeoma Ofurunna                          💃 😂 😱 😳 😘 😞 😜 😅 👆 🤣 🙏 👍 😭
# 7         Aunty Nkiru LSA  😇 😀 ❤ 🏿 ☠ 🚷 👆 ❕ ✔ 👇 ✅ 😥 ❌ 👍 😭 👏 ® 📌 🏴 🏻 © 👌 🙏 ...
# 8   Aunty Nkiru Onyianta                       💃 🚒 ❤ 👩 🏽 📌 🏿 🏾 😍 💥 🙏 🏫 🙄 😭 😓
# 9             Aunty Norah  😂 ❤ 👋 🥭 👩 🍏 🥕 🏅 👆 🍉 🍎 ♾ 😃 ✔ 💷 👇 😱 🥑 🍒 💪 🥦 👦 🤯 ...
# 10              Aunty Oby  ❤ 😂 😀 🤷 🏿 🤸 😒 👆 🙄 🥺 😃 👰 🚑 💃 👇 ♀ ‼ ✅ 🛩 🤣 😩 🎁 👍 ...
# 11    Aunty Oby Ozoemena
# ...

# %%
chat_emoji = chat_emoji.sort_values(by='Emoji Count', ascending=False)
print(chat_emoji.head(n=96))
# Out:
#                username                                              emoji  \
# 51           Pastor Cos  🌮 🏿 🍔 🐜 🏰 ⛵ 👎 😳 😭 🙌 👟 👀 🚗 💡 📲 👉 👳 🌘 💖 🔪 ✋ 😧 🤗 ...
# 53           Pastor Uba  👸 🏿 🙉 👎 🍸 😳 💯 🎹 🎯 🙌 😭 🥣 💁 🏾 👉 😆 😟 ✋ 🛎 🕺 💜 👂 🤲 ...
# 3     Aunty Ada Nkwueke  🤍 🌍 ☘ 😳 💯 🎹 😭 🙌 😊 😘 👉 🌞 ✋ 🤗 🕺 😂 👩 🤷 🤫 👆 💕 🛏 💥 ...
# 49              Mum MTN  👸 🍲 🏿 🥗 ☺ 🫂 😪 🍒 🛡 💐 🤣 🙌 😭 😉 💡 😊 💑 🅰 ✋ 📷 💜 👩 🤲 ...
# 71             ~ Adaeze  🍲 🏛 🌮 🥗 🍔 🚫 🍒 🤣 🥂 🍻 🥣 🚰 🍇 🏾 👉 🍑 💖 🍵 🤗 🍞 🤩 🍩 🤷 ...
# ..                  ...                                                ...
# 101       ~ Ozoqgu  U C                                                  🤲
# 60        Sis Ebere LSA                                                  ✋
# 42       Kene Ofurunna                                                   ☑
# 89         ~ Iyïnoluwa🙃                                                  🙃
# 55   Precious Achikanu                                                   🗣
#
#      Emoji Count
# 51           136
# 53            92
# ...

# %%
#Most active Emoji User
import plotly.express as px

figure = px.bar(chat_emoji, x='username',y='Emoji Count',title='Active Emoji users')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Top 20 Emoji Users
Top_emoji = chat_emoji.head(n=20)
figure = px.bar(Top_emoji, x='username',y='Emoji Count',title='Active 20 Emoji users',text =Top_emoji['Emoji Count'])
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Determining the most used Emoji

# %%
#Most Used Emoji

# Spliting the emojis into individual tokens
emoji_tokens = chat_emoji['emoji'].str.split()

emoji_list = [emoji for emojis in emoji_tokens for emoji in emojis]

# Counting the number of emojis
emoji_counts = pd.Series(emoji_list).value_counts().reset_index()

# Renaming the columns
emoji_counts.columns = ['Emoji', 'Count']

print(emoji_counts)
# Out:
#     Emoji  Count
# 0       🙏     69
# 1       😭     38
# 2       👍     36
# 3       🎂     33
# 4       ❤     32
# ..    ...    ...
# 473     👘      1
# 474     🔟      1
# 475     👖      1
# 476     👣      1
# 477     🐽      1
#
# [478 rows x 2 columns]

# %%
most_used_emoji = emoji_counts.head(n=10)

figure = px.bar(most_used_emoji, x='Emoji',y='Count',title='Emoji Frequently Used',text =most_used_emoji['Count'])
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### summary: The Most Used Emoji is the Prayer Emoji followed by the Crying emoji

# %%
#To check the overall usage of emojis in every conversation
fig = go.Figure(data=go.Pie(labels=['Chats without emoji', 'Chats with emoji'],
                            values=chat.assign(is_emoji=chat['emoji'].apply(lambda x: True if x != '' else False)).groupby('is_emoji').count()[['message']].reset_index()['message'],
                            hole=.4))
fig.update_traces(hoverinfo='label+value')
fig.update_layout(title='Emoji Usage in Each Conversation')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### summary: From the chats, only about 10.4% of our conversations contain emojis..while most of our conversations do not contain emoji

# %% [markdown]
# # Word Cloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

text = ' '.join(chat['clean_message'].dropna())

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # Most Frequent Words

# %%
freq_words = pd.Series(" ".join(chat['clean_message']).lower().split()).value_counts()[:50].reset_index()
freq_words.columns = ['word', 'count']
print(freq_words.head())
# Out:
#     word  count
# 0    god   8278
# 1   amen   7149
# 2  happy   4074
# 3      u   3922
# 4  jesus   3581

# %%
freq_words = freq_words.sort_values('count', ascending=False)

# Create a bar plot using Plotly
fig = go.Figure(data=[go.Bar(
    x=freq_words['count'],
    y=freq_words['word'],
    orientation='h'
)])

# Set the layout of the plot
fig.update_layout(
    title="Word Frequency",
    xaxis_title="Count",
    yaxis_title="Word"
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### summary : From the plot, God is the most frequent word used in this group since its a religious group, next is AMen and Happy which suggests the mood of the group is almost always positive.

# %% [markdown]
# # Sentiment Analysis using VADER

# %%
# initializing NLTK sentiment analyzer

analyzer = SentimentIntensityAnalyzer()

# creating a get_sentiment function

def get_sentiment(text):
    scores = analyzer.polarity_scores(text)

    if scores['compound'] >= 0.05:
        sentiment = 'positive'
    elif scores['compound'] <= -0.05:
        sentiment = 'negative'
    else:
        sentiment = 'neutral'

    return sentiment


# applying the get_sentiment function into the dataframe

chat['sentiment'] = chat['message'].apply(get_sentiment)

print(chat)
# Out:
#                                                  message  Positive  Negative  \
# 29552  Congratulations Precious and Iruoma 🫶🏽
# I pray ...     0.535       0.0
# 25564                                 Anty IJ thank you🫶     0.455       0.0
# 25565                                 Antyyyy Thank you🫶     0.556       0.0
# 30220                     Happy birthday Angel of Good🫠🥰     0.481       0.0
# 22866  🪴🪴🪴🌷🌷🪴🪴
#
#  *The Bible*
# The Bible is not a reli...     0.099       0.0
# ...                                                  ...       ...       ...
# 10601                                         Hallelujah     1.000       0.0
# 10600                                   Amen from sopuru     0.000       0.0
# 10599                                Amen from aunty ADA     0.000       0.0
# 10598                                   Amen from Samuel     0.000       0.0
# 30261                                     ‎video omitted     0.000       0.0
#
#        Neutral sentiment
# ...

# %%
fig = go.Figure(data=go.Pie(labels=['Negative', 'Neutral', 'Positive'],
                            values=chat.groupby('sentiment').count()[['message']].reset_index()['message'],hole = 0.3))
fig.update_traces(hoverinfo='label+value')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
