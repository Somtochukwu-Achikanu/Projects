# %% [markdown]
# <a href="https://colab.research.google.com/github/Somtochukwu-Achikanu/Projects/blob/main/Task_3_Car_price_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load Data
car_data = pd.read_csv('/content/car data.csv')
print(car_data.head())
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
print(car_data.info())
print(car_data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB
# None
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# ...

# %%
print(car_data['Fuel_Type'].value_counts())
# Out:
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
print(car_data['Selling_type'].value_counts())
# Out:
# Dealer        195
# Individual    106
# Name: Selling_type, dtype: int64

# %%
print(car_data['Transmission'].value_counts())
# Out:
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64

# %%
print(car_data['Owner'].value_counts())
# Out:
# 0    290
# 1     10
# 3      1
# Name: Owner, dtype: int64

# %% [markdown]
# check and remove duplicates

# %%
print(car_data.duplicated().sum())
print(car_data.drop_duplicates())
# Out:
# 2
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# ...

# %% [markdown]
# Visualization

# %%
heatmap = car_data.drop(['Car_Name','Fuel_Type','Selling_type'],axis =1)
sns.heatmap(heatmap.corr(),annot=True)
plt.show()
# Out:
# <ipython-input-197-a4b6028704ec>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(heatmap.corr(),annot=True)

# %%
sns.regplot(x='Present_Price',y='Selling_Price',data=car_data,ci=None)
plt.title('Selling Price vs Present Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.displot(data = car_data['Fuel_Type'], color ='k')
plt.title('Fuel Type Countplot')
plt.show()

# %% [markdown]
# summary: Petrol based car are more frequent and sold than other fuel type cars

# %%
sns.displot(data = car_data['Transmission'], color ='b')
plt.title('Transmission Countplot')
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='Car_Name',data =car_data,hue = 'Transmission')
plt.title('Countplot of Cars by their Transmission')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='Transmission',y='Selling_Price',data=car_data,errorbar=None)
plt.title('Transmission vs Selling Price')
plt.show()

# %% [markdown]
# From the visualisation, Automatic cars have higher selling prices than Manual cars..

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='Selling_type',y='Selling_Price',data=car_data,errorbar=None)
plt.title('Selling type vs Selling price')
plt.show()

# %% [markdown]
# Buying from Dealers are more expensive than individuals

# %%
sns.regplot(x='Driven_kms',y='Selling_Price',data=car_data,ci=None)
plt.title('Driven kms VS Selling Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='Year',y='Selling_Price',data=car_data,errorbar=None)
plt.title('Year VS Selling Price')
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='Car_Name',y='Selling_Price',data=car_data,errorbar=None)
plt.title('Car_name VS Selling Price')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(20,8))
sns.barplot(x='Car_Name',y='Present_Price',data=car_data,errorbar=None)
plt.title('Car_name VS Present Price')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Machine Learning

# %%
#Categorical data encoding

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
car_data['Fuel_Type'] = le.fit_transform(car_data['Fuel_Type'])
car_data['Transmission'] = le.fit_transform(car_data['Transmission'])
car_data['Selling_type'] = le.fit_transform(car_data['Selling_type'])
print(car_data.head())
print(car_data.shape)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          2
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          2
# 3  wagon r  2011           2.85           4.15        5200          2
# 4    swift  2014           4.60           6.87       42450          1
#
#    Selling_type  Transmission  Owner
# 0             0             1      0
# 1             0             1      0
# 2             0             1      0
# 3             0             1      0
# 4             0             1      0
# (301, 9)

# %% [markdown]
# For clarity sake - (Fuel -2, Diesel - 1, cng = 0)
# (Dealer = 0, Individual - 1)
# (Manual = 1, Automatic = 0)

# %%
X = car_data.drop(columns =['Car_Name','Selling_Price'], axis =1)
y = car_data['Selling_Price']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,mean_squared_error
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42)

# %% [markdown]
# ## 1. Linear regression

# %%
# Check shapes
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)

# Fit the model
lr = LinearRegression()
lr.fit(X_train, y_train)

# Predict on the test set
pred = lr.predict(X_test)

# Print shapes again for verification
print("y_test shape:", y_test.shape)
print("pred shape:", pred.shape)

#Mean absolute error
mae = mean_absolute_error(y_test, pred)
print('Mean absolute Error:', mae)

#Mean Squared error
mse = mean_squared_error(y_test, pred)
print('Mean square Error:', mse)

# R squared error
error_score = r2_score(y_test, pred)
print("R squared Error : ", error_score)
# Out:
# X_train shape: (210, 7)
# y_train shape: (210,)
# X_test shape: (91, 7)
# y_test shape: (91,)
# y_test shape: (91,)
# pred shape: (91,)
# Mean absolute Error: 1.2581987927234803
# Mean square Error: 3.495368886010676
# R squared Error :  0.8772443540167388

# %%
# Define the hyperparameter grid
param_grid = {'fit_intercept': [True, False]}

# Create GridSearchCV object
grid_search = GridSearchCV(lr, param_grid, cv=5, scoring='neg_mean_squared_error',n_jobs=-1)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

best_fit_intercept = grid_search.best_params_['fit_intercept']

# Use the best hyperparameters to train your final Linear Regression model
final_linear_model = LinearRegression(fit_intercept=best_fit_intercept)
final_linear_model.fit(X_train, y_train)

# Make predictions
y_pred_lr = final_linear_model.predict(X_test)

#Mean absolute error
mae_lr = mean_absolute_error(y_test, y_pred_lr)
print('Mean absolute Error:', mae)

#Mean Squared error
mse_lr = mean_squared_error(y_test, y_pred_lr)
print('Mean squared Error:', mse)

# R squared error
error_score_lr = r2_score(y_test, y_pred_lr)
print("R squared Error : ", error_score)
# Out:
# Mean absolute Error: 1.2581987927234803
# Mean squared Error: 3.495368886010676
# R squared Error :  0.8772443540167388

# %%
#Visualisation


plt.figure(figsize=(8, 8))
sns.set(style="whitegrid")

# Scatter plot
plt.scatter(y_test, y=y_pred, alpha=0.7, color='blue', edgecolors='w')

#a trendline or regression line
sns.regplot(x=y_test, y=y_pred, scatter=False, color='red')

#Labels and title
plt.xlabel('Original Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot of Original vs Predicted Values')


plt.show()

# %% [markdown]
# ##2. Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
# Fit the model
lasso_model = Lasso()
lasso_model.fit(X_train, y_train)

# Predict on the test set
pred = lasso_model.predict(X_test)

# Print shapes again for verification
print("y_test shape:", y_test.shape)
print("pred shape:", pred.shape)

#Mean absolute error
mae = mean_absolute_error(y_test, pred)
print('Mean absolute Error:', mae)

#Mean Squared error
mse = mean_squared_error(y_test, pred)
print('Mean square Error:', mse)


# R squared error
error_score = r2_score(y_test, pred)
print("R squared Error : ", error_score)
# Out:
# y_test shape: (91,)
# pred shape: (91,)
# Mean absolute Error: 1.4572107884364351
# Mean square Error: 4.569967135728412
# R squared Error :  0.8395049889830422

# %%
# Define the hyperparameter grid
param_grid = {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}

# Create GridSearchCV object
grid_search = GridSearchCV(lasso_model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_

# Create a new Elastic Net model with the best hyperparameters
best_lasso = Lasso(**best_params)

# Fit the model to the data
best_lasso.fit(X_train, y_train)

# Make predictions
y_pred = best_lasso.predict(X_test)

#Mean absolute error
mae_lasso = mean_absolute_error(y_test, y_pred)
print('Mean absolute Error:', mae)

#Mean Squared error
mse_lasso = mean_squared_error(y_test, y_pred)
print('Mean squared Error:', mse)

# R squared error
error_score_lasso = r2_score(y_test, y_pred)
print("R squared Error : ", error_score)
# Out:
# Mean absolute Error: 1.4572107884364351
# Mean squared Error: 4.569967135728412
# R squared Error :  0.8395049889830422

# %%
#Visualisation

plt.figure(figsize=(8, 8))
sns.set(style="whitegrid")

# Scatter plot
plt.scatter(y_test, y=y_pred, alpha=0.7, color='blue', edgecolors='w')

#a trendline or regression line
sns.regplot(x=y_test, y=y_pred, scatter=False, color='red')

#Labels and title
plt.xlabel('Original Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot of Original vs Predicted Values')


plt.show()

# %% [markdown]
# ##3. Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNet

# %%
# Fit the model
elastic_model = ElasticNet()
elastic_model.fit(X_train, y_train)

# Predict on the test set
pred = elastic_model.predict(X_test)

# Print shapes again for verification
print("y_test shape:", y_test.shape)
print("pred shape:", pred.shape)

#Mean absolute error
mae = mean_absolute_error(y_test, pred)
print('Mean absolute Error:', mae)

#Mean Squared error
mse = mean_squared_error(y_test, pred)
print('Mean squared Error:', mse)

# R squared error
error_score = r2_score(y_test, pred)
print("R squared Error : ", error_score)
# Out:
# y_test shape: (91,)
# pred shape: (91,)
# Mean absolute Error: 1.432449420241416
# Mean squared Error: 4.386908107590118
# R squared Error :  0.8459339325323542

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Define the hyperparameter grid
param_grid = {
    'alpha': [0.1, 0.5, 1.0],
    'l1_ratio': [0.1, 0.5, 0.9],
}

# Create GridSearchCV object
grid_search = GridSearchCV(elastic_model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_

# Create a new Elastic Net model with the best hyperparameters
best_elastic_net = ElasticNet(**best_params)

# Fit the model to the data
best_elastic_net.fit(X_train, y_train)

# Make predictions
y_pred_em = best_elastic_net.predict(X_test)

#Mean absolute error
mae_elastic = mean_absolute_error(y_test, y_pred_em)
print('Mean absolute Error:', mae)

#Mean Squared error
mse_elastic = mean_squared_error(y_test, y_pred_em)
print('Mean squared Error:', mse)

# R squared error
error_score_elastic = r2_score(y_test, y_pred_em)
print("R squared Error : ", error_score)
# Out:
# Mean absolute Error: 1.432449420241416
# Mean squared Error: 4.386908107590118
# R squared Error :  0.8459339325323542

# %%
#Visualisation


plt.figure(figsize=(8, 8))
sns.set(style="whitegrid")

# Scatter plot
plt.scatter(y_test, y=y_pred_em, alpha=0.7, color='blue', edgecolors='w')

#a trendline or regression line
sns.regplot(x=y_test, y=y_pred_em, scatter=False, color='red')

#Labels and title
plt.xlabel('Original Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot of Original vs Predicted Values')


plt.show()

# %%
data = {'models': ['Linear Regression','Lasso Regression','Elastic Net'],
        'MAE':  [mae_lr, mae_lasso, mae_elastic],
        'MSE':    [mse_lr, mse_lasso,mse_elastic],
        'R squared error':[error_score_lr,error_score_lasso,error_score_elastic] }

df = pd.DataFrame(data)
df.sort_values(by=['MAE','MSE','R squared error'],ascending=False)
# Out:
#               models       MAE       MSE  R squared error
# 2        Elastic Net  1.263537  3.601030         0.873534
# 0  Linear Regression  1.258199  3.495369         0.877244
# 1   Lasso Regression  1.257651  3.494220         0.877285
